# %%
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt

# %%
x = cv2.imread('CEDAR_database/full_forg/forgeries_1_1.png', 0)

# %%
all_forg = os.listdir('CEDAR_database/full_forg')

# %% [markdown]
# for i in all_forg:

# %%
x.shape
# Out:
# (438, 588)

# %%
x1 = cv2.Sobel(x,cv2.CV_64F,1,1,ksize=3)
plt.imshow(x, cmap = 'gray')
plt.show()

# %%
x2 = cv2.equalizeHist(x)
plt.imshow(x2, cmap = 'gray')
plt.show()

# %%
ret, x3 = cv2.threshold(x2,250,255,cv2.THRESH_TOZERO)
plt.imshow(x3, cmap = 'gray')
plt.show()

# %%
x4 = cv2.resize(x,(240, 160),interpolation=cv2.INTER_AREA)
plt.imshow(x4, cmap = 'gray')
plt.show()

# %%
ret, x5 = cv2.threshold(x4,250,255,cv2.THRESH_TOZERO)
plt.imshow(x5, cmap = 'gray')
plt.show()
